# %%
# IMPORTS 
import pandas as pd
import numpy as np
import shutil
import os
import time
import subprocess
import sys
import datetime
import matplotlib.pyplot as plt
from os.path import exists as file_exists
import matplotlib.dates as mdates
import math
import matplotlib.ticker as mtick

og_wd = os.getcwd()

# FILE PATH
data_file_path = r"C:\Users\govertsen.k\Desktop\trial"
data_file_path = data_file_path.replace(os.sep, '/')

# CONSTANTS
year = os.listdir(data_file_path + "/actual/outage/")

otg_start = os.listdir(data_file_path + "/actual/outage/" + year[0])
otg_start = [int(x) for x in otg_start]
otg_start.sort()

# Identify all the models
models = os.listdir(data_file_path + "/actual/outage/" + year[0] + "/" + str(otg_start[0]))

# Make new Outputs folders
new_path = data_file_path + "/actual/" + "output"
if not os.path.exists(new_path):
    os.makedirs(new_path)
new_path = data_file_path + "/actual/" + "output/" + year[0]
if not os.path.exists(new_path):
    os.makedirs(new_path)                 
for each_otg_start in otg_start:
    new_path = data_file_path + "/actual/output/" + year[0] + "/" + str(each_otg_start)
    print(new_path)
    if not os.path.exists(new_path):
        os.makedirs(new_path)
# Out:
# 2001
# C:/Users/govertsen.k/Desktop/trial/actual/output/2001/8
# C:/Users/govertsen.k/Desktop/trial/actual/output/2001/12
# C:/Users/govertsen.k/Desktop/trial/actual/output/2001/20

# %%
print(otg_start)
# Out:
# [8, 12, 20]

# %%
program_name = "/ReadVarsESO.exe"
source = data_file_path + program_name
    
# for each_study in study:
#     for each_model in models:
#         # Copy, Paste and Read Vars ESO
#         new_path = data_file_path + "/actual/baseline/" + each_study + "/" + each_model + "/"
#         destination = new_path + program_name
#         shutil.copyfile(source,destination)

#         # change to that folder
#         os.chdir(os.path.abspath(new_path))

#         # run readvarseso
#         subprocess.run(["ReadVarsESO"], shell=True)

#         # Move eplusout CSV to outputs
#         old_location = new_path + "eplusout.csv"

#         new_location = data_file_path + "/actual/output" + "/" + each_study + "/" + each_model + ".csv"
#         shutil.copyfile(old_location,new_location)

#         # Delete ReadVarsEso.exe from the folder
#         os.remove(destination)

#         os.chdir(og_wd)

# %%
program_name = "/ReadVarsESO.exe"
source = data_file_path + program_name

for each_otg_start in otg_start:
    for each_model in models:

        # Copy, Paste and Read Vars ESO
        new_path = data_file_path + "/actual/outage/" + year[0] + "/" + each_otg_start + "/" + each_model
        destination = new_path + program_name

        shutil.copyfile(source,destination)

        # change to that folder
        os.chdir(os.path.abspath(new_path))

        # run readvarseso
        subprocess.run(["ReadVarsESO"], shell=True)

        # Move eplusout CSV to outputs
        old_location = new_path + "/eplusout.csv"
        new_location = data_file_path + "/actual/output/" + year[0] + "/" + each_otg_start + "/" + each_model + ".csv"
        shutil.copyfile(old_location,new_location)

        # Delete ReadVarsEso.exe from the folder
        os.remove(destination)

        os.chdir(og_wd)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#      20 old_location = new_path + "/eplusout.csv"
#      21 new_location = data_file_path + "/actual/output/" + year[0] + "/" + each_otg_start + "/" + each_model + ".csv"
# ---> 22 shutil.copyfile(old_location,new_location)
#      24 # Delete ReadVarsEso.exe from the folder
#      25 os.remove(destination)
#
# File ~\Anaconda3\lib\shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
#     267                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/govertsen.k/Desktop/trial/actual/outage/2001/12/bldg0164955/eplusout.csv'

# %%
models
# Out:
# ['bldg0002642',
#  'bldg0003104',
#  'bldg0006733',
#  'bldg0009153',
#  'bldg0010160',
#  'bldg0010982',
#  'bldg0012954',
#  'bldg0013107',
#  'bldg0013299',
#  'bldg0014965',
#  'bldg0016262',
#  'bldg0018503',
#  'bldg0018951',
#  'bldg0020026',
#  'bldg0020718',
#  'bldg0021633',
#  'bldg0022011',
#  'bldg0022095',
#  'bldg0031322',
#  'bldg0031601',
#  'bldg0031815',
#  'bldg0032647',
#  'bldg0032763',
#  'bldg0034178',
#  'bldg0034709',
#  'bldg0036219',
#  'bldg0039312',
#  'bldg0040504',
#  'bldg0044383',
#  'bldg0046397',
#  'bldg0046792',
#  'bldg0048629',
#  'bldg0049140',
#  'bldg0050469',
#  'bldg0052784',
#  'bldg0052855',
#  'bldg0054192',
#  'bldg0056405',
#  'bldg0057323',
#  'bldg0059297',
#  'bldg0059401',
#  'bldg0060377',
#  'bldg0062353',
#  'bldg0065995',
#  'bldg0067153',
#  'bldg0070493',
#  'bldg0073497',
#  'bldg0074528',
#  'bldg0077034',
#  'bldg0080561',
#  'bldg0081498',
#  'bldg0083137',
#  'bldg0083286',
#  'bldg0084539',
#  'bldg0087182',
#  'bldg0088424',
#  'bldg0090245',
#  'bldg0092057',
#  'bldg0092990',
#  'bldg0098329',
#  'bldg0099054',
#  'bldg0100855',
#  'bldg0101727',
#  'bldg0105694',
#  'bldg0106811',
#  'bldg0107877',
#  'bldg0107968',
#  'bldg0109150',
#  'bldg0110181',
#  'bldg0113578',
#  'bldg0113798',
#  'bldg0116792',
#  'bldg0119975',
#  'bldg0122124',
#  'bldg0122905',
#  'bldg0126032',
#  'bldg0126038',
#  'bldg0126882',
#  'bldg0127884',
#  'bldg0128974',
#  'bldg0130188',
#  'bldg0131583',
#  'bldg0132722',
#  'bldg0133100',
#  'bldg0133525',
#  'bldg0139159',
#  'bldg0139334',
#  'bldg0143583',
#  'bldg0144983',
#  'bldg0147899',
#  'bldg0148400',
#  'bldg0149686',
#  'bldg0153246',
#  'bldg0154325',
#  'bldg0154757',
#  'bldg0156483',
#  'bldg0159357',
#  'bldg0159380',
#  'bldg0162053',
#  'bldg0162695',
#  'bldg0163114',
#  'bldg0163725',
#  'bldg0164955',
#  'bldg0171499',
#  'bldg0173965',
#  'bldg0176285',
#  'bldg0176517',
#  'bldg0178357',
#  'bldg0180142',
#  'bldg0180363',
#  'bldg0181465',
#  'bldg0183947',
#  'bldg0184914',
#  'bldg0187266',
#  'bldg0191425',
#  'bldg0191825',
#  'bldg0193328',
#  'bldg0194296',
#  'bldg0195484',
#  'bldg0196932',
#  'bldg0199158',
#  'bldg0200559',
#  'bldg0200783',
#  'bldg0202455',
#  'bldg0207582',
#  'bldg0210030',
#  'bldg0216396',
#  'bldg0217453',
#  'bldg0218694',
#  'bldg0218885',
#  'bldg0219175',
#  'bldg0221423',
#  'bldg0227937',
#  'bldg0230494',
#  'bldg0230781',
#  'bldg0230904',
#  'bldg0232575',
#  'bldg0232814',
#  'bldg0234468',
#  'bldg0237797',
#  'bldg0238163',
#  'bldg0238770',
#  'bldg0238856',
#  'bldg0241406',
#  'bldg0241736',
#  'bldg0241840',
#  'bldg0242495',
#  'bldg0243104',
#  'bldg0243196',
#  'bldg0244320',
#  'bldg0251082',
#  'bldg0257596',
#  'bldg0261643',
#  'bldg0262237',
#  'bldg0263541',
#  'bldg0269257',
#  'bldg0276386',
#  'bldg0279463',
#  'bldg0281023',
#  'bldg0282472',
#  'bldg0283380',
#  'bldg0286653',
#  'bldg0286751',
#  'bldg0288751',
#  'bldg0292695',
#  'bldg0295059',
#  'bldg0298416',
#  'bldg0298932',
#  'bldg0299166',
#  'bldg0300229',
#  'bldg0301388',
#  'bldg0301513',
#  'bldg0301784',
#  'bldg0303310',
#  'bldg0303571',
#  'bldg0307751',
#  'bldg0308703',
#  'bldg0310768',
#  'bldg0311946',
#  'bldg0313128',
#  'bldg0318240',
#  'bldg0320236',
#  'bldg0322965',
#  'bldg0323713',
#  'bldg0324513',
#  'bldg0325767',
#  'bldg0327676',
#  'bldg0330573',
#  'bldg0332530',
#  'bldg0333566',
#  'bldg0335224',
#  'bldg0339973',
#  'bldg0341745',
#  'bldg0342749',
#  'bldg0344593',
#  'bldg0345689',
#  'bldg0347915',
#  'bldg0348497',
#  'bldg0349658',
#  'bldg0352185',
#  'bldg0354538',
#  'bldg0355650',
#  'bldg0356583',
#  'bldg0357975',
#  'bldg0359229',
#  'bldg0361410',
#  'bldg0363886',
#  'bldg0364418',
#  'bldg0368766',
#  'bldg0368867',
#  'bldg0370074',
#  'bldg0370610',
#  'bldg0371249',
#  'bldg0374869',
#  'bldg0375114',
#  'bldg0377561',
#  'bldg0378410',
#  'bldg0379600',
#  'bldg0380178',
#  'bldg0383605',
#  'bldg0385407',
#  'bldg0395049',
#  'bldg0395759',
#  'bldg0398385',
#  'bldg0399246',
#  'bldg0399371',
#  'bldg0403719',
#  'bldg0404847',
#  'bldg0409660',
#  'bldg0410905',
#  'bldg0411576',
#  'bldg0412743',
#  'bldg0412957',
#  'bldg0414579',
#  'bldg0415753',
#  'bldg0416169',
#  'bldg0416348',
#  'bldg0418913',
#  'bldg0419058',
#  'bldg0422378',
#  'bldg0423145',
#  'bldg0425693',
#  'bldg0428470',
#  'bldg0432468',
#  'bldg0433976',
#  'bldg0435601',
#  'bldg0436640',
#  'bldg0437627',
#  'bldg0437913',
#  'bldg0440638',
#  'bldg0440751',
#  'bldg0442908',
#  'bldg0444024',
#  'bldg0444833',
#  'bldg0447269',
#  'bldg0447360',
#  'bldg0451184',
#  'bldg0452525',
#  'bldg0452747',
#  'bldg0454443',
#  'bldg0455721',
#  'bldg0455891',
#  'bldg0456438',
#  'bldg0458330',
#  'bldg0459016',
#  'bldg0461989',
#  'bldg0462890',
#  'bldg0463472',
#  'bldg0464006',
#  'bldg0464302',
#  'bldg0464946',
#  'bldg0465314',
#  'bldg0465788',
#  'bldg0465939',
#  'bldg0469184',
#  'bldg0471066',
#  'bldg0471672',
#  'bldg0472707',
#  'bldg0476037',
#  'bldg0481041',
#  'bldg0481400',
#  'bldg0485037',
#  'bldg0485741',
#  'bldg0487892',
#  'bldg0488323',
#  'bldg0490680',
#  'bldg0492101',
#  'bldg0494306',
#  'bldg0502447',
#  'bldg0503083',
#  'bldg0504331',
#  'bldg0504430',
#  'bldg0507060',
#  'bldg0508008',
#  'bldg0508095',
#  'bldg0508285',
#  'bldg0508525',
#  'bldg0509811',
#  'bldg0509927',
#  'bldg0513927',
#  'bldg0517994',
#  'bldg0518369',
#  'bldg0519387',
#  'bldg0520248',
#  'bldg0524194',
#  'bldg0527700',
#  'bldg0528109',
#  'bldg0533187',
#  'bldg0534041',
#  'bldg0535065',
#  'bldg0536627',
#  'bldg0539572',
#  'bldg0539770',
#  'bldg0544793',
#  'bldg0547838']
